# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Downloads/Major Commercial crops.xlsx",index_col=0)

# %%
df.head()
# Out:
#       Groundnut  Rapeseed & Mustered  Soyabean  Total Oilseeds  Coffee $  \
# Year
# 1950         35                    8         0              52         0
# 1951         32                    9         0              50         0
# 1952         29                    9         0              47         0
# 1953         35                    9         0              54         0
# 1954         43                   10         0              64         0
#
#       Cotton @ (Lint)  Raw Jute & Mesta  Sugarcane  Tea $  Tobacco
# Year
# 1950               30                33        571      0        3
# 1951               33                47        616      0        2
# 1952               33                53        510      0        3
# 1953               41                38        444      0        3
# 1954               45                39        587      0        3

# %%
crop_data = df.copy(deep = True)

# %%
crop_data.head()
# Out:
#       Groundnut  Rapeseed & Mustered  Soyabean  Total Oilseeds  Coffee $  \
# Year
# 1950         35                    8         0              52         0
# 1951         32                    9         0              50         0
# 1952         29                    9         0              47         0
# 1953         35                    9         0              54         0
# 1954         43                   10         0              64         0
#
#       Cotton @ (Lint)  Raw Jute & Mesta  Sugarcane  Tea $  Tobacco
# Year
# 1950               30                33        571      0        3
# 1951               33                47        616      0        2
# 1952               33                53        510      0        3
# 1953               41                38        444      0        3
# 1954               45                39        587      0        3

# %% [markdown]
# Investigating the Dataset
# --

# %%
crop_data.index
# Out:
# Int64Index([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#             1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#             1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#             1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#             1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#             2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#             2016, 2017, 2018, 2019, 2020, 2021],
#            dtype='int64', name='Year')

# %%
crop_data.columns
# Out:
# Index(['Groundnut', 'Rapeseed & Mustered', 'Soyabean', 'Total Oilseeds',
#        'Coffee $', 'Cotton @ (Lint)', 'Raw Jute & Mesta', 'Sugarcane', 'Tea $',
#        'Tobacco'],
#       dtype='object')

# %%
crop_data.shape
# Out:
# (72, 10)

# %%
crop_data.size
# Out:
# 720

# %%
crop_data.dtypes
# Out:
# Groundnut              int64
# Rapeseed & Mustered    int64
# Soyabean               int64
# Total Oilseeds         int64
# Coffee $               int64
# Cotton @ (Lint)        int64
# Raw Jute & Mesta       int64
# Sugarcane              int64
# Tea $                  int64
# Tobacco                int64
# dtype: object

# %%
crop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 1950 to 2021
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Groundnut            72 non-null     int64
#  1   Rapeseed & Mustered  72 non-null     int64
#  2   Soyabean             72 non-null     int64
#  3   Total Oilseeds       72 non-null     int64
#  4   Coffee $             72 non-null     int64
#  5   Cotton @ (Lint)      72 non-null     int64
#  6   Raw Jute & Mesta     72 non-null     int64
#  7   Sugarcane            72 non-null     int64
#  8   Tea $                72 non-null     int64
#  9   Tobacco              72 non-null     int64
# dtypes: int64(10)
# memory usage: 6.2 KB

# %%
crop_data.corr()
# Out:
#                      Groundnut  Rapeseed & Mustered  Soyabean  Total Oilseeds  \
# Groundnut             1.000000             0.739611  0.606667        0.781841
# Rapeseed & Mustered   0.739611             1.000000  0.932784        0.980812
# Soyabean              0.606667             0.932784  1.000000        0.961390
# Total Oilseeds        0.781841             0.980812  0.961390        1.000000
# Coffee $              0.680221             0.905277  0.882773        0.919365
# Cotton @ (Lint)       0.618605             0.878396  0.945299        0.914748
# Raw Jute & Mesta      0.597812             0.768889  0.756528        0.794204
# Sugarcane             0.726726             0.942924  0.913526        0.953659
# Tea $                 0.728621             0.910176  0.864386        0.920769
# Tobacco               0.563811             0.647765  0.663670        0.696783
#
#                      Coffee $  Cotton @ (Lint)  Raw Jute & Mesta  Sugarcane  \
# ...

# %% [markdown]
# Checking Null Values
# --

# %%
crop_data.isnull()
# Out:
#       Groundnut  Rapeseed & Mustered  Soyabean  Total Oilseeds  Coffee $  \
# Year
# 1950      False                False     False           False     False
# 1951      False                False     False           False     False
# 1952      False                False     False           False     False
# 1953      False                False     False           False     False
# 1954      False                False     False           False     False
# ...         ...                  ...       ...             ...       ...
# 2017      False                False     False           False     False
# 2018      False                False     False           False     False
# 2019      False                False     False           False     False
# 2020      False                False     False           False     False
# 2021      False                False     False           False     False
#
#       Cotton @ (Lint)  Raw Jute & Mesta  Sugarcane  Tea $  Tobacco
# Year
# ...

# %%
crop_data.isnull().sum()
# Out:
# Groundnut              0
# Rapeseed & Mustered    0
# Soyabean               0
# Total Oilseeds         0
# Coffee $               0
# Cotton @ (Lint)        0
# Raw Jute & Mesta       0
# Sugarcane              0
# Tea $                  0
# Tobacco                0
# dtype: int64

# %%
crop_data.describe()
# Out:
#         Groundnut  Rapeseed & Mustered    Soyabean  Total Oilseeds  \
# count   72.000000            72.000000   72.000000       72.000000
# mean    63.263889            40.166667   39.180556      164.236111
# std     18.050003            28.656292   47.489162       96.517457
# min     29.000000             8.000000    0.000000       47.000000
# 25%     50.000000            14.000000    0.000000       76.250000
# 50%     61.000000            29.000000    9.500000      127.000000
# 75%     75.000000            63.000000   72.750000      245.000000
# max    102.000000           118.000000  147.000000      377.000000
#
#           Coffee $  Cotton @ (Lint)  Raw Jute & Mesta    Sugarcane  \
# count    72.000000        72.000000         72.000000    72.000000
# mean   1562.597222       128.708333         83.875000  2077.972222
# std    1222.789407       103.728986         23.276015  1066.062770
# min       0.000000        30.000000         33.000000   444.000000
# ...

# %%
plt.boxplot(crop_data)
plt.xlabel("crops")
plt.show()

# %%
sns.boxplot(data=crop_data,x="Cotton @ (Lint)")
# Out:
# <AxesSubplot:xlabel='Cotton @ (Lint)'>

# %% [markdown]
# Analysis
# --

# %%
sns.axes_style("whitegrid")
sns.scatterplot(crop_data["Rapeseed & Mustered"],crop_data["Total Oilseeds"])
# Out:
# C:\Users\om123\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rapeseed & Mustered', ylabel='Total Oilseeds'>

# %%
sns.axes_style("whitegrid")
sns.scatterplot(crop_data["Coffee $"],crop_data["Tea $"])
# Out:
# C:\Users\om123\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Coffee $', ylabel='Tea $'>

# %%
sns.histplot(data=crop_data,x="Groundnut",kde=True)
# Out:
# <AxesSubplot:xlabel='Groundnut', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Rapeseed & Mustered",kde=True)
# Out:
# <AxesSubplot:xlabel='Rapeseed & Mustered', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Soyabean",kde=True)
# Out:
# <AxesSubplot:xlabel='Soyabean', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Total Oilseeds",kde=True)
# Out:
# <AxesSubplot:xlabel='Total Oilseeds', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Coffee $",kde=True)
# Out:
# <AxesSubplot:xlabel='Coffee $', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Cotton @ (Lint)",kde=True)
# Out:
# <AxesSubplot:xlabel='Cotton @ (Lint)', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Raw Jute & Mesta",kde=True)
# Out:
# <AxesSubplot:xlabel='Raw Jute & Mesta', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Sugarcane",kde=True)
# Out:
# <AxesSubplot:xlabel='Sugarcane', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Tea $",kde=True)
# Out:
# <AxesSubplot:xlabel='Tea $', ylabel='Count'>

# %%
sns.histplot(data=crop_data,x="Tobacco",kde=True)
# Out:
# <AxesSubplot:xlabel='Tobacco', ylabel='Count'>

# %%
sns.lineplot(data=crop_data)
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.show()

# %%
plt.plot(crop_data["Groundnut"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Groundnut")
plt.show()

# %%
plt.plot(crop_data["Rapeseed & Mustered"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Rapeseed & Mustered")
plt.show()

# %%
plt.plot(crop_data["Soyabean"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Soyabean")
plt.show()

# %%
plt.plot(crop_data["Total Oilseeds"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Total Oilseeds")
plt.show()

# %%
plt.plot(crop_data["Coffee $"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Coffee")
plt.show()

# %%
plt.plot(crop_data["Cotton @ (Lint)"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Cotton")
plt.show()

# %%
plt.plot(crop_data["Raw Jute & Mesta"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Raw Jute & Mesta")
plt.show()

# %%
plt.plot(crop_data["Sugarcane"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Sugarcane")
plt.show()

# %%
plt.plot(crop_data["Tea $"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Tea")
plt.show()

# %%
plt.plot(crop_data["Tobacco"])
plt.xlabel("Year")
plt.ylabel("Production (Lakhs Tonnes)")
plt.title("Tobacco")
plt.show()
